# %% [markdown]
# <a href="https://colab.research.google.com/github/hitarthi45/GENAI/blob/main/Genai_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q groq

from groq import Groq

GROQ_API_KEY = "YOUR_GROQ_API_KEY"

client = Groq(api_key=GROQ_API_KEY)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.4 MB/s eta 0:00:00
# HITL stands for Human-In-The-Loop. In the context of LangGraph, a large language model, HITL refers to a process where human evaluators are involved in the loop of generating and improving the model's responses.
#
# Here's a simplified overview of how HITL works in LangGraph:
#
# 1. **Model generates response**: LangGraph generates a response to a given input or question.
# 2. **Human evaluation**: A human evaluator reviews the response to check its accuracy, relevance, and quality.
# 3. **Feedback loop**: The human evaluator provides feedback on the response, such as correcting errors, suggesting improvements, or rating the response.
# 4. **Model updating**: The feedback is used to update and fine-tune the LangGraph model, so it can learn from its mistakes and improve its performance.
# ...

# %%
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain everything you know about Marwadi University."
        }
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Marwadi University is a private university located in Rajkot, Gujarat, India. Here's an overview of what I know about the university:
#
# **History and Establishment**: Marwadi University was established in 2016 by the Marwadi Education Foundation, a trust founded by the Marwadi family. The university is recognized by the University Grants Commission (UGC) and is approved by the All India Council for Technical Education (AICTE).
#
# **Academics**: Marwadi University offers a wide range of undergraduate, postgraduate, and doctoral programs in various fields, including:
#
# 1. Engineering (B.Tech, M.Tech, Ph.D.)
# 2. Management (BBA, MBA, Ph.D.)
# 3. Law (BA LLB, B.Com LLB, LL.M, Ph.D.)
# 4. Science (B.Sc, M.Sc, Ph.D.)
# 5. Commerce (B.Com, M.Com, Ph.D.)
# 6. Arts (BA, MA, Ph.D.)
# 7. Pharmacy (B.Pharm, M.Pharm, Ph.D.)
# 8. Computer Applications (BCA, MCA, Ph.D.)
#
# ...
